# %% [markdown]
# ## Import Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import ast
from empiricaldist import Pmf

# %% [markdown]
# ## Load Record

# %%
bot_record = pd.read_csv('fitness.csv')
bot_record['fitnesses'] = bot_record['fitnesses'].apply(lambda x: ast.literal_eval(x))
bot_record.head()
# Out:
#    epoch  max_pos     max_fit       fit_sum
# 0      0      473  153.478449  30391.269860  \
# 1      1      291  174.547422  35695.583696
# 2      2      245  203.237939  37048.160404
# 3      3      474  203.237939  37623.619404
# 4      4      100  203.237939  37855.490523
#
#                                            fitnesses
# 0  [33.99160307418579, 28.49601580196225, 95.6231...
# 1  [76.39020038616802, 85.00536102344184, 6.68168...
# 2  [50.486347439810764, 132.57781591487472, 54.30...
# 3  [46.757768071545925, 100.0, 82.79043311319307,...
# 4  [100.0, 0.04835552381075481, 100.0, 100.0, 0.0...

# %% [markdown]
# ## Fit Sum

# %%
plt.figure(figsize=(10, 5))
sns.set(font_scale=1.2)
sns.lineplot(data=bot_record, x='epoch', y='fit_sum')
plt.show()

# %% [markdown]
# ## Max Fit

# %%
plt.figure(figsize=(10, 5))
sns.set(font_scale=1.2)
sns.lineplot(data=bot_record, x='epoch', y='max_fit')
plt.show()

# %% [markdown]
# ## PMF

# %%
pmf_epoch_1 = Pmf.from_seq(bot_record.iloc[0]['fitnesses'])
pmf_epoch_30 = Pmf.from_seq(bot_record.iloc[29]['fitnesses'])
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
pmf_epoch_1.plot(label='Epoch 1', color='C0')
plt.xlabel('fitness')
plt.ylabel('PMF')
plt.legend()
plt.subplot(1,2,2)
pmf_epoch_30.plot(label='Epoch 30', color='C1')
plt.xlabel('fitness')
plt.ylabel('PMF')
plt.legend()
plt.show()
